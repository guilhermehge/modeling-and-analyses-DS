# %% [markdown]
# # Modelagem Estatística
#
# ### Banco de 2021
#
# Para a modelagem estatística, irei utilizar uma árvore de decisão pois acredito ser a melhor opção para visualizar quais variáveis são mais e menos importantes na hora de determinar o óbito.
#
# ### Transformação das variáveis de idade e tempo de alta e óbito em categóricas
#
# No caso deste problema, há apenas 2 variáveis que não são categóricas, idade e tempo de alta ou óbito. Isso faz com que a árvore de decisão seja enviesada pois estas duas variáveis possibilitam infinitas quebras na árvore, a tornando muito importantes quando analisamos o feature importances e o SHAP. Desse modo, vou transformá-las em categóricas utilizando o pd.cut e ver como ficará o modelo.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SRAG_2020_2021.csv', parse_dates=['DT_NOTIFIC'])

df = df[df['tempo_alta_obito_final'] >= 0]

# %%
df['idade1'] = pd.qcut(df['idade'], q=5)

# %%
df['tempo_alta_obito_final1'] = pd.qcut(df['tempo_alta_obito_final'], q=5)

# %%
df['idade1'].value_counts().sort_index()
# Out:
# (-0.001, 39.0]    502254
# (39.0, 52.0]      447026
# (52.0, 63.0]      478908
# (63.0, 75.0]      497105
# (75.0, 121.0]     444562
# Name: idade1, dtype: int64

# %%
df['tempo_alta_obito_final1'].value_counts().sort_index()
# Out:
# (-0.001, 14.0]    506975
# (14.0, 36.0]      449796
# (36.0, 85.0]      466670
# (85.0, 162.0]     477281
# (162.0, 703.0]    469133
# Name: tempo_alta_obito_final1, dtype: int64

# %%
df.to_csv('SRAG_2020_2021_idade_tempo_cat.csv', index=False)

# %% [markdown]
# ## Seleção das variáveis numéricas e categóricas
#
# Também irei retirar algumas variáveis da análise, como Raça e Estado.

# %%
delete_vars = ['raca', 'SG_UF_NOT', 'EVOLUCAO', 'DT_NOTIFIC', 'idade', 'tempo_alta_obito_final']
num_vars = []
dummy_vars = ['gravidez', 'mae_amamenta', 'mae_vacinada_gripe', 'positivo_vsr', 'positivo_para1', 'positivo_para2', 
              'positivo_para3', 'positivo_para4', 'positivo_adeno', 'positivo_sars2', 'positivo_influenza', 'positivo_metap',
             'positivo_boca', 'positivo_rino']

cat_vars = [i for i in df.columns if (i not in delete_vars) and (i not in num_vars) and (i not in dummy_vars)]

model_vars = cat_vars + num_vars + dummy_vars

# %%
model_vars
# Out:
# ['febre',
#  'tosse',
#  'dispneia',
#  'diarreia',
#  'vomito',
#  'garganta',
#  'desc_resp',
#  'saturacao',
#  'dor_abd',
#  'fadiga',
#  'perd_olft',
#  'perd_pala',
#  'hematologi',
#  'cardiopati',
#  'asma',
#  'diabetes',
#  'pneumopati',
#  'renal',
#  'imunodepre',
#  'hepatica',
#  'neurologic',
#  'obesidade',
#  'puerpera',
#  'sind_down',
#  'CS_SEXO',
#  'vacina_gripe',
#  'diagnostico',
#  'antiviral',
#  'suporte_vent',
#  'uti',
#  'vacina_covid19',
#  'idade1',
#  'tempo_alta_obito_final1',
#  'gravidez',
#  'mae_amamenta',
#  'mae_vacinada_gripe',
#  'positivo_vsr',
#  'positivo_para1',
#  'positivo_para2',
#  'positivo_para3',
#  'positivo_para4',
#  'positivo_adeno',
#  'positivo_sars2',
#  'positivo_influenza',
#  'positivo_metap',
#  'positivo_boca',
#  'positivo_rino']

# %%
len(model_vars)
# Out:
# 47

# %% [markdown]
# ### Separando em treino e teste (OOT)
#
# O banco de teste será OOT (Out of time). Pode-se ver pela variável DT_NOTIFIC que o banco vai de 29/12/2019 até 09/12/2021 (provável erro). Vou utilizar como treino os casos do início até 31 de junho de 2021. A partir de 01 de julho de 2021 será utilizado como teste (OOT).
#
# Essa divisão traz uma proporção de, aproximadamente 19,7% para teste

# %%
df[['DT_NOTIFIC']].describe(datetime_is_numeric=True)
# Out:
#                           DT_NOTIFIC
# count                        2253859
# mean   2021-01-07 18:38:20.275573248
# min              2019-12-29 00:00:00
# 25%              2020-08-09 00:00:00
# 50%              2021-02-04 00:00:00
# 75%              2021-05-23 00:00:00
# max              2021-12-09 00:00:00

# %%
data_corte = pd.to_datetime('2021-07-01')

df_train = df[df['DT_NOTIFIC'] <= data_corte].reset_index().copy()
df_test = df[df['DT_NOTIFIC'] >= data_corte].reset_index().copy()

# %%
df_train.shape, df_test.shape
# Out:
# ((1887549, 54), (371071, 54))

# %%
X_train = df_train[model_vars].copy()
y_train = df_train['EVOLUCAO'].copy()

X_test = df_test[model_vars].copy()
y_test = df_test['EVOLUCAO'].copy()

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.689379
# 1    0.310621
# Name: EVOLUCAO, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.699645
# 1    0.300355
# Name: EVOLUCAO, dtype: float64

# %% [markdown]
# A proporção entre 0 e 1 de teste e treino é próxima.

# %% [markdown]
# ## Modelagem - Árvore de decisão

# %%
from sklearn.pipeline import Pipeline
from feature_engine.encoding import OneHotEncoder
from feature_engine.wrappers import SklearnTransformerWrapper

from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.metrics import accuracy_score

# %% [markdown]
# Para não ter que aplicar em cada loop a transformação das colunas categóricas em dummy, vou fazer o processo apenas 1 vez e aplicar no modelo

# %%
onehot = OneHotEncoder()

# %%
X_train_transf = onehot.fit_transform(X_train)

X_test_transf = onehot.transform(X_test)
# Out:
# C:\Users\guilh\anaconda3\envs\fia-tcc\lib\site-packages\feature_engine\encoding\one_hot.py:276: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[str(feature) + "_" + str(category)] = np.where(

# %%
X_train_transf.shape, X_test_transf.shape
# Out:
# ((1887549, 148), (371071, 148))

# %% [markdown]
# ### Baseline - Modelo sem ajuste de hiperparâmetros

# %%
dt = Pipeline(steps=[
    ('dt', DecisionTreeClassifier(random_state=42))
])

# %%
dt.fit(X_train_transf, y_train)
# Out:
# Pipeline(steps=[('dt', DecisionTreeClassifier(random_state=42))])

# %% [markdown]
# ## Avaliação do modelo

# %% [markdown]
# ### Acurácia

# %%
y_pred_train = dt.predict(X_train_transf)
y_pred_test = dt.predict(X_test_transf)
from sklearn.metrics import accuracy_score

print('Acurácia Treino:', accuracy_score(y_train, y_pred_train))
print('Acurácia Teste:', accuracy_score(y_test, y_pred_test))
# Out:
# Acurácia Treino: 0.976693055385582
# Acurácia Teste: 0.7255080564096897

# %% [markdown]
# ### AUROC

# %%
from sklearn.metrics import roc_auc_score

y_proba = dt.predict_proba(X_train_transf)[:, 1]

y_proba_test = dt.predict_proba(X_test_transf)[:, 1]


print('AUC Treino:', roc_auc_score(y_train, y_proba))
print('AUC Teste:', roc_auc_score(y_test, y_proba_test))
# Out:
# AUC Treino: 0.9985612411115857
# AUC Teste: 0.6825516286439779

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=['Alta', 'Obito']))
# Out:
#               precision    recall  f1-score   support
#
#         Alta       0.81      0.79      0.80    259618
#        Obito       0.54      0.56      0.55    111453
#
#     accuracy                           0.73    371071
#    macro avg       0.68      0.68      0.68    371071
# weighted avg       0.73      0.73      0.73    371071

# %% [markdown]
# ## Feature Importances
#
# Entendendo quais são as características que não podem faltar na triagem de um paciente com suspeita de SRAG

# %%
pd.set_option('display.max_rows', 148)

feature_importances_df = pd.DataFrame({
    'features': X_train_transf.columns,
    'importances': dt.steps[-1][1].feature_importances_
}).sort_values(by='importances', ascending=False)

feature_importances_df
# Out:
#                                    features  importances
# 125                   suporte_vent_Invasivo     0.192038
# 140                    idade1_(75.0, 121.0]     0.046037
# 129                                 uti_Nao     0.031931
# 141                     idade1_(63.0, 75.0]     0.021510
# 9                            positivo_sars2     0.017376
# 119                       diagnostico_COVID     0.016191
# 115                   vacina_gripe_Ignorado     0.015536
# 120                           antiviral_Nao     0.015106
# 14                                febre_Sim     0.015055
# 143   tempo_alta_obito_final1_(84.0, 161.0]     0.014538
# 144  tempo_alta_obito_final1_(161.0, 703.0]     0.014522
# 146    tempo_alta_obito_final1_(35.0, 84.0]     0.014420
# 112                        vacina_gripe_Nao     0.014167
# 138                   idade1_(-0.001, 39.0]     0.013664
# 67                           cardiopati_Sim     0.013469
# 145    tempo_alta_obito_final1_(14.0, 35.0]     0.013101
# 111                               CS_SEXO_F     0.012571
# 110                               CS_SEXO_M     0.012308
# 35                             garganta_Sim     0.011772
# 114                       vacina_gripe_Nulo     0.011719
# 122                      antiviral_Ignorado     0.011314
# 42                            saturacao_Sim     0.011210
# 15                                febre_Nao     0.011154
# 18                                tosse_Sim     0.010989
# 134                     vacina_covid19_Nulo     0.010909
# 133           vacina_covid19_Nao-disponivel     0.010872
# 75                             diabetes_Sim     0.010750
# 22                             dispneia_Sim     0.010664
# 52                               fadiga_Sim     0.010493
# 147  tempo_alta_obito_final1_(-0.001, 14.0]     0.009996
# 27                             diarreia_Sim     0.009970
# 123                          antiviral_Nulo     0.009415
# 113                        vacina_gripe_Sim     0.009316
# 121                           antiviral_Sim     0.009290
# 34                             garganta_Nao     0.008959
# 51                               fadiga_Nao     0.008323
# 31                               vomito_Sim     0.008244
# 38                            desc_resp_Sim     0.008196
# 68                           cardiopati_Nao     0.008054
# 135                      vacina_covid19_Nao     0.008024
# 137                 vacina_covid19_Ignorado     0.007898
# 66                          cardiopati_Nulo     0.007734
# 26                             diarreia_Nao     0.007616
# 43                            saturacao_Nao     0.007277
# 19                                tosse_Nao     0.007072
# 136                      vacina_covid19_Sim     0.007062
# 24                             dispneia_Nao     0.006899
# 100                           obesidade_Sim     0.006427
# 30                               vomito_Nao     0.006398
# 76                             diabetes_Nao     0.006032
# 16                               febre_Nulo     0.006027
# 78                           pneumopati_Sim     0.005955
# 44                           saturacao_Nulo     0.005458
# 74                            diabetes_Nulo     0.005423
# 139                     idade1_(53.0, 63.0]     0.005388
# 36                            garganta_Nulo     0.005209
# 126                        suporte_vent_Nao     0.005191
# 124               suporte_vent_Nao-invasivo     0.005121
# 48                              dor_abd_Sim     0.005079
# 47                              dor_abd_Nao     0.004888
# 96                           neurologic_Sim     0.004823
# 127                       suporte_vent_Nulo     0.004746
# 99                            obesidade_Nao     0.004721
# 50                              fadiga_Nulo     0.004635
# 56                            perd_olft_Sim     0.004609
# 25                            dispneia_Nulo     0.004602
# 60                            perd_pala_Sim     0.004588
# 39                            desc_resp_Nao     0.004482
# 84                                renal_Sim     0.004441
# 130                                 uti_Sim     0.004284
# 55                            perd_olft_Nao     0.004231
# 59                            perd_pala_Nao     0.004157
# 20                               tosse_Nulo     0.004149
# 28                            diarreia_Nulo     0.004020
# 86                           imunodepre_Sim     0.003951
# 131                                uti_Nulo     0.003947
# 98                           obesidade_Nulo     0.003894
# 72                                 asma_Sim     0.003801
# 40                           desc_resp_Nulo     0.003518
# 80                           pneumopati_Nao     0.003485
# 142                     idade1_(39.0, 53.0]     0.003435
# 32                              vomito_Nulo     0.003392
# 128                   suporte_vent_Ignorado     0.002982
# 54                           perd_olft_Nulo     0.002930
# 58                           perd_pala_Nulo     0.002792
# 46                             dor_abd_Nulo     0.002738
# 71                                 asma_Nao     0.002711
# 95                           neurologic_Nao     0.002485
# 83                                renal_Nao     0.002397
# 79                          pneumopati_Nulo     0.002375
# 93                             hepatica_Sim     0.002346
# 82                               renal_Nulo     0.002217
# 70                                asma_Nulo     0.002144
# 117                diagnostico_Desconhecido     0.002029
# 94                          neurologic_Nulo     0.001917
# 103                            puerpera_Nao     0.001903
# 65                           hematologi_Sim     0.001883
# 88                           imunodepre_Nao     0.001811
# 132                            uti_Ignorado     0.001732
# 102                           puerpera_Nulo     0.001691
# 87                          imunodepre_Nulo     0.001646
# 91                             hepatica_Nao     0.001497
# 45                       saturacao_Ignorado     0.001475
# 37                        garganta_Ignorado     0.001416
# 101                      obesidade_Ignorado     0.001333
# 90                            hepatica_Nulo     0.001311
# 63                           hematologi_Nao     0.001299
# 17                           febre_Ignorado     0.001153
# 62                          hematologi_Nulo     0.001114
# 104                       puerpera_Ignorado     0.001063
# 53                          fadiga_Ignorado     0.000998
# 61                       perd_pala_Ignorado     0.000988
# 107                           sind_down_Nao     0.000984
# 57                       perd_olft_Ignorado     0.000970
# 29                        diarreia_Ignorado     0.000966
# 33                          vomito_Ignorado     0.000867
# 49                         dor_abd_Ignorado     0.000861
# 108                           sind_down_Sim     0.000842
# 21                           tosse_Ignorado     0.000776
# 106                          sind_down_Nulo     0.000759
# 41                       desc_resp_Ignorado     0.000720
# 23                        dispneia_Ignorado     0.000680
# 0                                  gravidez     0.000639
# 116                      diagnostico_Outros     0.000566
# 1                              mae_amamenta     0.000559
# 69                      cardiopati_Ignorado     0.000445
# 77                        diabetes_Ignorado     0.000368
# 105                            puerpera_Sim     0.000363
# 81                      pneumopati_Ignorado     0.000330
# 73                            asma_Ignorado     0.000313
# 85                           renal_Ignorado     0.000291
# 89                      imunodepre_Ignorado     0.000288
# 64                      hematologi_Ignorado     0.000254
# 92                        hepatica_Ignorado     0.000251
# 109                      sind_down_Ignorado     0.000246
# 97                      neurologic_Ignorado     0.000236
# 3                              positivo_vsr     0.000186
# 13                            positivo_rino     0.000170
# 118                   diagnostico_Influenza     0.000154
# 10                       positivo_influenza     0.000151
# 2                        mae_vacinada_gripe     0.000048
# 8                            positivo_adeno     0.000043
# 11                           positivo_metap     0.000032
# 4                            positivo_para1     0.000015
# 6                            positivo_para3     0.000006
# 12                            positivo_boca     0.000005
# 7                            positivo_para4     0.000002
# 5                            positivo_para2     0.000000

# %%
pd.reset_option('display.max_rows')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (10,7))
plt.title("Feature importances")
sns.barplot(data = feature_importances_df[:15], x = 'importances', y = 'features')
plt.show()

# %% [markdown]
# **OBSERVAÇÃO**
#
# Observa-se uma grande mudança no feature importance em  comparação com o modelo sem alterar as variáveis de idade e tempo de alta. Antes, estas duas variáveis tinham uma importância muito alta pois traziam o viés de serem numéricas. Este modelo é melhor pois remove o viés numérico destas variáveis, assim conseguimos analisar quais faixas desempenham a maior importância no modelo

# %%
# import shap

# explainer = shap.Explainer(dt.steps[-1][1])
# shap_values = explainer(X_test_transf)

# shap.plots.beeswarm(shap_values[:, :, 1], max_display = 20)

# O SHAP para o modelo baseline demora demais pois a árvore não tem profundidade limitada

# %% [markdown]
# ### Modelo com ajuste de hiperparâmetros
#
# Através dos testes anteriores, foi possível observar que a profundidade que trazia maior acurácia era a de 12. Como duas variáveis foram alteradas, vou refazer este teste para ver o que acontecerá.

# %%
# %%time

profundidade = []
acuracia = []

for depth in range(1, 31):
    dt = Pipeline(steps=[
        ('dt', DecisionTreeClassifier(random_state=42, max_depth=depth))
    ])
    
    dt.fit(X_train_transf, y_train)
    
    y_pred_train = dt.predict(X_train_transf)
    train_accuracy = accuracy_score(y_train, y_pred_train)
    y_pred_test = dt.predict(X_test_transf)
    test_accuracy = accuracy_score(y_test, y_pred_test)
    
    y_proba = dt.predict_proba(X_train_transf)[:, 1]
    y_proba_test = dt.predict_proba(X_test_transf)[:, 1]
    
    profundidade.append(depth)
    acuracia.append(test_accuracy)
    
    print('Profundidade:', depth)
    print('Acurácia Treino:', train_accuracy)
    print('Acurácia Teste:', test_accuracy)
    print('AUC Treino:', roc_auc_score(y_train, y_proba))
    print('AUC Teste:', roc_auc_score(y_test, y_proba_test))
    print('')
# Out:
# Profundidade: 1
# Acurácia Treino: 0.7724032594650523
# Acurácia Teste: 0.7855639486782853
# AUC Treino: 0.6705255087169306
# AUC Teste: 0.6815458945720658
#
# Profundidade: 2
# Acurácia Treino: 0.7728223214337747
# Acurácia Teste: 0.7851624082722714
# AUC Treino: 0.7383287084070983
# AUC Teste: 0.7450076200002851
#
# Profundidade: 3
# Acurácia Treino: 0.7833778089999253
# Acurácia Teste: 0.7959339317812494
# AUC Treino: 0.7846324371665604
# AUC Teste: 0.7963036844435687
#
# Profundidade: 4
# Acurácia Treino: 0.7876929287663526
# Acurácia Teste: 0.799634032301096
# AUC Treino: 0.8089880411095168
# AUC Teste: 0.8172288857498168
#
# Profundidade: 5
# Acurácia Treino: 0.7881019247712244
# Acurácia Teste: 0.7997579977955701
# AUC Treino: 0.8237171311282271
# AUC Teste: 0.8332609062154563
#
# Profundidade: 6
# Acurácia Treino: 0.7916435546838784
# Acurácia Teste: 0.801337210399088
# AUC Treino: 0.8301234231120229
# AUC Teste: 0.8390536670673827
#
# Profundidade: 7
# Acurácia Treino: 0.7926369063796489
# Acurácia Teste: 0.8021834096439765
# AUC Treino: 0.8335106004888723
# AUC Teste: 0.8413459275025671
#
# Profundidade: 8
# Acurácia Treino: 0.7941844158747667
# Acurácia Teste: 0.8024043916123869
# AUC Treino: 0.8363306298393665
# AUC Teste: 0.8430655958643118
#
# Profundidade: 9
# Acurácia Treino: 0.7955597444092842
# Acurácia Teste: 0.8034095900784486
# AUC Treino: 0.8391920242569013
# AUC Teste: 0.8451516861337938
#
# Profundidade: 10
# Acurácia Treino: 0.7972524156988772
# Acurácia Teste: 0.8048082442443629
# AUC Treino: 0.8416822063098569
# AUC Teste: 0.8463810923383308
#
# Profundidade: 11
# Acurácia Treino: 0.7991283934880631
# Acurácia Teste: 0.8059589674213291
# AUC Treino: 0.8444404557252606
# AUC Teste: 0.8472940267046847
#
# Profundidade: 12
# Acurácia Treino: 0.8008051711505237
# Acurácia Teste: 0.8048783116977614
# AUC Treino: 0.8474212024430181
# AUC Teste: 0.8470745024258659
#
# Profundidade: 13
# Acurácia Treino: 0.80341384515051
# Acurácia Teste: 0.8048944811100841
# AUC Treino: 0.8509103687768874
# AUC Teste: 0.8458863440369879
#
# Profundidade: 14
# Acurácia Treino: 0.8063928406626795
# Acurácia Teste: 0.8041102646124326
# AUC Treino: 0.8551731206141073
# AUC Teste: 0.8431973918549075
#
# Profundidade: 15
# Acurácia Treino: 0.8101183068624973
# Acurácia Teste: 0.8029730159457354
# AUC Treino: 0.860375204979491
# AUC Teste: 0.8387852748264312
#
# Profundidade: 16
# Acurácia Treino: 0.8146040182268116
# Acurácia Teste: 0.8013776339298948
# AUC Treino: 0.8664939072455038
# AUC Teste: 0.8331407935704784
#
# Profundidade: 17
# Acurácia Treino: 0.8199818918608206
# Acurácia Teste: 0.7994130503326856
# AUC Treino: 0.8735979502803674
# AUC Teste: 0.825607968112822
#
# Profundidade: 18
# Acurácia Treino: 0.8262132532718356
# Acurácia Teste: 0.7970711804479467
# AUC Treino: 0.8816156766092081
# AUC Teste: 0.8160441127179858
#
# Profundidade: 19
# Acurácia Treino: 0.8331269810743986
# Acurácia Teste: 0.7942657874099566
# AUC Treino: 0.8904311366863769
# AUC Teste: 0.8058917865475991
#
# Profundidade: 20
# Acurácia Treino: 0.8408375093838624
# Acurácia Teste: 0.7905764664983251
# AUC Treino: 0.8999432296628439
# AUC Teste: 0.7942956953143274
#
# Profundidade: 21
# Acurácia Treino: 0.8491610019130629
# Acurácia Teste: 0.7870811785345662
# AUC Treino: 0.9098003752725978
# AUC Teste: 0.7826357124133471
#
# Profundidade: 22
# Acurácia Treino: 0.8578881925714247
# Acurácia Teste: 0.7826857932848431
# AUC Treino: 0.9197393505180674
# AUC Teste: 0.7701170460145481
#
# Profundidade: 23
# Acurácia Treino: 0.8669978898561044
# Acurácia Teste: 0.7789344896259746
# AUC Treino: 0.9295297538427212
# AUC Teste: 0.7582519179794851
#
# Profundidade: 24
# Acurácia Treino: 0.8762405638211247
# Acurácia Teste: 0.7750430510603092
# AUC Treino: 0.9388756280078538
# AUC Teste: 0.7470737725675485
#
# Profundidade: 25
# Acurácia Treino: 0.8853629760075102
# Acurácia Teste: 0.7704078195277992
# AUC Treino: 0.9476532912619924
# AUC Teste: 0.7360067507334511
#
# Profundidade: 26
# Acurácia Treino: 0.8943624774774059
# Acurácia Teste: 0.7665972280237475
# AUC Treino: 0.955753401230873
# AUC Teste: 0.7265610324835027
#
# Profundidade: 27
# Acurácia Treino: 0.9031786724477087
# Acurácia Teste: 0.7619296576665922
# AUC Treino: 0.9630227462993796
# AUC Teste: 0.7178918239571147
#
# Profundidade: 28
# Acurácia Treino: 0.911473556448071
# Acurácia Teste: 0.7577525594832256
# AUC Treino: 0.969328672817289
# AUC Teste: 0.70966950068765
#
# Profundidade: 29
# Acurácia Treino: 0.91934884869214
# Acurácia Teste: 0.7531685310897376
# AUC Treino: 0.9748368220704775
# AUC Teste: 0.7027304070361899
#
# Profundidade: 30
# Acurácia Treino: 0.9267626959618002
# Acurácia Teste: 0.7504736290359527
# AUC Treino: 0.9795120044859067
# AUC Teste: 0.6982324828740178
#
# Wall time: 28min 21s

# %% [markdown]
# Observando os resultados é possível notar que há um aumento da acurácia tanto de treino quanto de teste com o aumento da profundidade da árvore, porém, treino e teste passam a divergir a partir dos 15 de profundidade, onde a acurácia de treino aumenta e a de teste diminui, o que indica o início de um _overfit_. É possível observar este mesmo comportamento, também, no AUC. Na casa dos 25 de profundidade já é possível observar a lacuna entre treino e teste, mostrando o _overfit_.
#
# Como há muitas variáveis no banco, uma árvore com profundidade 7 apresenta um bom _trade-off_ nos seguintes quesitos:
# * Possibilidade de ler a árvore
# * Não haver overfit
# * Bons números de acurácia e AUC

# %%
result_profundidade = pd.DataFrame(profundidade, columns=['Profundidade'])
result_profundidade['Acuracia'] = acuracia
result_profundidade
# Out:
#     Profundidade  Acuracia
# 0              1  0.785564
# 1              2  0.785162
# 2              3  0.795934
# 3              4  0.799634
# 4              5  0.799758
# 5              6  0.801337
# 6              7  0.802183
# 7              8  0.802404
# 8              9  0.803410
# 9             10  0.804808
# 10            11  0.805959
# 11            12  0.804878
# 12            13  0.804894
# 13            14  0.804110
# 14            15  0.802973
# 15            16  0.801378
# 16            17  0.799413
# 17            18  0.797071
# 18            19  0.794266
# 19            20  0.790576
# 20            21  0.787081
# 21            22  0.782686
# 22            23  0.778934
# 23            24  0.775043
# 24            25  0.770408
# 25            26  0.766597
# 26            27  0.761930
# 27            28  0.757753
# 28            29  0.753169
# 29            30  0.750474

# %%
result_profundidade.to_csv('resultados_loop_profundidade_ajuste_idade_tempo.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (12,8))
sns.lineplot(x = profundidade, y = acuracia)
plt.show()

# %%
print('Maior acurácia:', max(acuracia), '\nProfundidade:', acuracia.index(max(acuracia))+1)
# Out:
# Maior acurácia: 0.8059589674213291
# Profundidade: 11

# %% [markdown]
# Análise do min_samples_leaf

# %%
# %%time

samp_leaf = [2, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000, 5000, 10000]

acuracia = []

for samples_leaf in samp_leaf:
    dt = Pipeline(steps=[
        # ('one_hot_encoder', OneHotEncoder(variables=cat_vars)),
        ('dt', DecisionTreeClassifier(random_state=42, max_depth=7, min_samples_leaf=samples_leaf))
    ])
    
    dt.fit(X_train_transf, y_train)
    
    y_pred_train = dt.predict(X_train_transf)
    train_accuracy = accuracy_score(y_train, y_pred_train)
    y_pred_test = dt.predict(X_test_transf)
    test_accuracy = accuracy_score(y_test, y_pred_test)
    
    y_proba = dt.predict_proba(X_train_transf)[:, 1]
    y_proba_test = dt.predict_proba(X_test_transf)[:, 1]

    acuracia.append(test_accuracy)
    
    print('min_samples_leaf:', samples_leaf)
    print('Acurácia Treino:', train_accuracy)
    print('Acurácia Teste:', test_accuracy)
    print('AUC Treino:', roc_auc_score(y_train, y_proba))
    print('AUC Teste:', roc_auc_score(y_test, y_proba_test))
    print('')
# Out:
# min_samples_leaf: 2
# Acurácia Treino: 0.7926369063796489
# Acurácia Teste: 0.8021834096439765
# AUC Treino: 0.8335106004888723
# AUC Teste: 0.8413459275025671
#
# min_samples_leaf: 100
# Acurácia Treino: 0.7926188936022324
# Acurácia Teste: 0.8021941892521917
# AUC Treino: 0.8334982467660174
# AUC Teste: 0.8413387740367343
#
# min_samples_leaf: 200
# Acurácia Treino: 0.7925685637829799
# Acurácia Teste: 0.8021537657213849
# AUC Treino: 0.8334905579081583
# AUC Teste: 0.8413444952507455
#
# min_samples_leaf: 300
# Acurácia Treino: 0.7925500212179922
# Acurácia Teste: 0.8022157484686219
# AUC Treino: 0.8334855945646116
# AUC Teste: 0.8413423989635377
#
# min_samples_leaf: 400
# Acurácia Treino: 0.7925161148134433
# Acurácia Teste: 0.8021887994480841
# AUC Treino: 0.8334727240288755
# AUC Teste: 0.8413313914900981
#
# min_samples_leaf: 500
# Acurácia Treino: 0.7925055190620217
# Acurácia Teste: 0.8021887994480841
# AUC Treino: 0.833439791936263
# AUC Teste: 0.8413116958977944
#
# min_samples_leaf: 600
# Acurácia Treino: 0.7925055190620217
# Acurácia Teste: 0.8021887994480841
# AUC Treino: 0.8334250164730153
# AUC Teste: 0.8413414725660906
#
# min_samples_leaf: 700
# Acurácia Treino: 0.7924954530981713
# Acurácia Teste: 0.8021753249378152
# AUC Treino: 0.8334116117355355
# AUC Teste: 0.8413160695319263
#
# min_samples_leaf: 800
# Acurácia Treino: 0.7924684339320462
# Acurácia Teste: 0.8021699351337076
# AUC Treino: 0.8333789295672713
# AUC Teste: 0.8413095297821541
#
# min_samples_leaf: 900
# Acurácia Treino: 0.7924583679681958
# Acurácia Teste: 0.8021322065049545
# AUC Treino: 0.8333697429262604
# AUC Teste: 0.8413017356261993
#
# min_samples_leaf: 1000
# Acurácia Treino: 0.7924578381806248
# Acurácia Teste: 0.8021214268967395
# AUC Treino: 0.8333627971285182
# AUC Teste: 0.84128286769349
#
# min_samples_leaf: 2000
# Acurácia Treino: 0.7922294997374902
# Acurácia Teste: 0.8021645453296
# AUC Treino: 0.8330999019706116
# AUC Teste: 0.8411599366478778
#
# min_samples_leaf: 5000
# Acurácia Treino: 0.7915005120396874
# Acurácia Teste: 0.8011404825491617
# AUC Treino: 0.8325288343709035
# AUC Teste: 0.8409623753204537
#
# min_samples_leaf: 10000
# Acurácia Treino: 0.7905792114535835
# Acurácia Teste: 0.799884658192098
# AUC Treino: 0.8316861709035929
# AUC Teste: 0.8403573249837503
#
# Wall time: 7min 33s

# %%
plt.figure(figsize = (12,8))
sns.lineplot(x = samp_leaf, y = acuracia)
plt.show()

# %% [markdown]
# Como a acurácia vai descendo com o aumento do min_samples_leaf, vou utilizar 2000 para tentar diminuir o tamanho da árvore que será plotada.
#
# Além disso, vou utilizar class_weight = 'balanced' para tentar balancear os 0 e 1

# %%
dt = Pipeline(steps=[
    ('dt', DecisionTreeClassifier(random_state=42, max_depth=7, min_samples_leaf=2000, class_weight = 'balanced'))
])

# %%
dt.fit(X_train_transf, y_train)
# Out:
# Pipeline(steps=[('dt',
#                  DecisionTreeClassifier(class_weight='balanced', max_depth=7,
#                                         min_samples_leaf=2000,
#                                         random_state=42))])

# %% [markdown]
# ## Avaliação do modelo

# %% [markdown]
# ### Acurácia

# %%
y_pred_train = dt.predict(X_train_transf)
y_pred_test = dt.predict(X_test_transf)
from sklearn.metrics import accuracy_score

print('Acurácia Treino:', accuracy_score(y_train, y_pred_train))
print('Acurácia Teste:', accuracy_score(y_test, y_pred_test))
# Out:
# Acurácia Treino: 0.760505819981362
# Acurácia Teste: 0.7688744202591957

# %% [markdown]
# ### AUROC

# %%
from sklearn.metrics import roc_auc_score

y_proba = dt.predict_proba(X_train_transf)[:, 1]

y_proba_test = dt.predict_proba(X_test_transf)[:, 1]


print('AUC Treino:', roc_auc_score(y_train, y_proba))
print('AUC Teste:', roc_auc_score(y_test, y_proba_test))
# Out:
# AUC Treino: 0.8333214732323113
# AUC Teste: 0.8413517775043302

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=['Alta', 'Obito']))
# Out:
#               precision    recall  f1-score   support
#
#         Alta       0.87      0.78      0.83    259618
#        Obito       0.59      0.74      0.66    111453
#
#     accuracy                           0.77    371071
#    macro avg       0.73      0.76      0.74    371071
# weighted avg       0.79      0.77      0.78    371071

# %% [markdown]
# ## Feature Importances
#
# Entendendo quais são as características que não podem faltar na triagem de um paciente com suspeita de SRAG

# %%
pd.set_option('display.max_rows', 148)

feature_importances_df = pd.DataFrame({
    'features': X_train_transf.columns,
    'importances': dt.steps[-1][1].feature_importances_
}).sort_values(by='importances', ascending=False)

feature_importances_df
# Out:
#                                    features  importances
# 125                   suporte_vent_Invasivo     0.488970
# 140                    idade1_(75.0, 121.0]     0.164030
# 129                                 uti_Nao     0.118696
# 138                   idade1_(-0.001, 39.0]     0.061063
# 141                     idade1_(63.0, 75.0]     0.044680
# 119                       diagnostico_COVID     0.036274
# 142                     idade1_(39.0, 53.0]     0.026818
# 139                     idade1_(53.0, 63.0]     0.020832
# 126                        suporte_vent_Nao     0.012831
# 147  tempo_alta_obito_final1_(-0.001, 14.0]     0.005412
# 38                            desc_resp_Sim     0.004152
# 98                           obesidade_Nulo     0.002391
# 130                                 uti_Sim     0.002169
# 18                                tosse_Sim     0.001709
# 133           vacina_covid19_Nao-disponivel     0.001454
# 42                            saturacao_Sim     0.001424
# 96                           neurologic_Sim     0.001224
# 131                                uti_Nulo     0.001165
# 39                            desc_resp_Nao     0.001029
# 86                           imunodepre_Sim     0.000868
# 43                            saturacao_Nao     0.000860
# 115                   vacina_gripe_Ignorado     0.000345
# 22                             dispneia_Sim     0.000307
# 71                                 asma_Nao     0.000236
# 110                               CS_SEXO_M     0.000229
# 74                            diabetes_Nulo     0.000145
# 55                            perd_olft_Nao     0.000140
# 87                          imunodepre_Nulo     0.000131
# 127                       suporte_vent_Nulo     0.000124
# 128                   suporte_vent_Ignorado     0.000105
# 95                           neurologic_Nao     0.000085
# 83                                renal_Nao     0.000058
# 47                              dor_abd_Nao     0.000027
# 54                           perd_olft_Nulo     0.000015
# 15                                febre_Nao     0.000000
# 108                           sind_down_Sim     0.000000
# 109                      sind_down_Ignorado     0.000000
# 112                        vacina_gripe_Nao     0.000000
# 111                               CS_SEXO_F     0.000000
# 106                          sind_down_Nulo     0.000000
# 113                        vacina_gripe_Sim     0.000000
# 114                       vacina_gripe_Nulo     0.000000
# 14                                febre_Sim     0.000000
# 107                           sind_down_Nao     0.000000
# 105                            puerpera_Sim     0.000000
# 117                diagnostico_Desconhecido     0.000000
# 104                       puerpera_Ignorado     0.000000
# 103                            puerpera_Nao     0.000000
# 102                           puerpera_Nulo     0.000000
# 101                      obesidade_Ignorado     0.000000
# 100                           obesidade_Sim     0.000000
# 99                            obesidade_Nao     0.000000
# 16                               febre_Nulo     0.000000
# 97                      neurologic_Ignorado     0.000000
# 17                           febre_Ignorado     0.000000
# 94                          neurologic_Nulo     0.000000
# 93                             hepatica_Sim     0.000000
# 92                        hepatica_Ignorado     0.000000
# 91                             hepatica_Nao     0.000000
# 116                      diagnostico_Outros     0.000000
# 120                           antiviral_Nao     0.000000
# 118                   diagnostico_Influenza     0.000000
# 13                            positivo_rino     0.000000
# 146    tempo_alta_obito_final1_(35.0, 84.0]     0.000000
# 145    tempo_alta_obito_final1_(14.0, 35.0]     0.000000
# 144  tempo_alta_obito_final1_(161.0, 703.0]     0.000000
# 143   tempo_alta_obito_final1_(84.0, 161.0]     0.000000
# 2                        mae_vacinada_gripe     0.000000
# 3                              positivo_vsr     0.000000
# 4                            positivo_para1     0.000000
# 5                            positivo_para2     0.000000
# 6                            positivo_para3     0.000000
# 137                 vacina_covid19_Ignorado     0.000000
# 136                      vacina_covid19_Sim     0.000000
# 135                      vacina_covid19_Nao     0.000000
# 134                     vacina_covid19_Nulo     0.000000
# 7                            positivo_para4     0.000000
# 132                            uti_Ignorado     0.000000
# 8                            positivo_adeno     0.000000
# 9                            positivo_sars2     0.000000
# 10                       positivo_influenza     0.000000
# 11                           positivo_metap     0.000000
# 12                            positivo_boca     0.000000
# 124               suporte_vent_Nao-invasivo     0.000000
# 123                          antiviral_Nulo     0.000000
# 122                      antiviral_Ignorado     0.000000
# 121                           antiviral_Sim     0.000000
# 89                      imunodepre_Ignorado     0.000000
# 90                            hepatica_Nulo     0.000000
# 26                             diarreia_Nao     0.000000
# 88                           imunodepre_Nao     0.000000
# 41                       desc_resp_Ignorado     0.000000
# 56                            perd_olft_Sim     0.000000
# 53                          fadiga_Ignorado     0.000000
# 52                               fadiga_Sim     0.000000
# 51                               fadiga_Nao     0.000000
# 50                              fadiga_Nulo     0.000000
# 49                         dor_abd_Ignorado     0.000000
# 48                              dor_abd_Sim     0.000000
# 46                             dor_abd_Nulo     0.000000
# 45                       saturacao_Ignorado     0.000000
# 44                           saturacao_Nulo     0.000000
# 21                           tosse_Ignorado     0.000000
# 23                        dispneia_Ignorado     0.000000
# 40                           desc_resp_Nulo     0.000000
# 27                             diarreia_Sim     0.000000
# 24                             dispneia_Nao     0.000000
# 25                            dispneia_Nulo     0.000000
# 37                        garganta_Ignorado     0.000000
# 36                            garganta_Nulo     0.000000
# 35                             garganta_Sim     0.000000
# 34                             garganta_Nao     0.000000
# 33                          vomito_Ignorado     0.000000
# 32                              vomito_Nulo     0.000000
# 31                               vomito_Sim     0.000000
# 30                               vomito_Nao     0.000000
# 29                        diarreia_Ignorado     0.000000
# 28                            diarreia_Nulo     0.000000
# 57                       perd_olft_Ignorado     0.000000
# 58                           perd_pala_Nulo     0.000000
# 59                            perd_pala_Nao     0.000000
# 60                            perd_pala_Sim     0.000000
# 19                                tosse_Nao     0.000000
# 85                           renal_Ignorado     0.000000
# 84                                renal_Sim     0.000000
# 82                               renal_Nulo     0.000000
# 81                      pneumopati_Ignorado     0.000000
# 80                           pneumopati_Nao     0.000000
# 79                          pneumopati_Nulo     0.000000
# 78                           pneumopati_Sim     0.000000
# 77                        diabetes_Ignorado     0.000000
# 76                             diabetes_Nao     0.000000
# 75                             diabetes_Sim     0.000000
# 1                              mae_amamenta     0.000000
# 73                            asma_Ignorado     0.000000
# 72                                 asma_Sim     0.000000
# 20                               tosse_Nulo     0.000000
# 70                                asma_Nulo     0.000000
# 69                      cardiopati_Ignorado     0.000000
# 68                           cardiopati_Nao     0.000000
# 67                           cardiopati_Sim     0.000000
# 66                          cardiopati_Nulo     0.000000
# 65                           hematologi_Sim     0.000000
# 64                      hematologi_Ignorado     0.000000
# 63                           hematologi_Nao     0.000000
# 62                          hematologi_Nulo     0.000000
# 61                       perd_pala_Ignorado     0.000000
# 0                                  gravidez     0.000000

# %%
pd.reset_option('display.max_rows')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (10,7))
plt.title("Feature importances")
sns.barplot(data = feature_importances_df[:15], x = 'importances', y = 'features')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 25, 10

# %%
plot_tree(
    dt.steps[-1][1],
    feature_names=X_train_transf.columns,
    class_names=['Alta', 'Obito'],
    rounded=True,
    filled=True,
    proportion=True
);

plt.savefig('tree_7_2000_cat.pdf',format='pdf')

# %%
import shap

explainer = shap.Explainer(dt.steps[-1][1])
shap_values = explainer(X_test_transf)

shap.plots.beeswarm(shap_values[:, :, 1], max_display = 20) # 1 é o óbito e 0 a alta

# %% [markdown]
# Pode-se observar que o class_weight = 'balanced' faz diferença no modelo, melhorando os verdadeiros positivos, mas, em contra partida, piora os falsos positivos. Como estamos tratando de óbitos, um falso negativo é pior que um falso positivo, portanto podemos seguir desta forma.

# %% [markdown]
# ## Modelagem - Regressão Logística

# %% [markdown]
# No caso da regressão logística, é necessário aplicar o parâmetro drop_last = True ao dummificar as colunas

# %%
onehot = OneHotEncoder(drop_last = True)

# %%
X_train_transf = onehot.fit_transform(X_train)

X_test_transf = onehot.transform(X_test)
# Out:
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
X_train_transf.shape, X_test_transf.shape
# Out:
# ((1887549, 115), (371071, 115))

# %% [markdown]
# ### Modelo Baseline

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = Pipeline(steps=[
    ('lr', LogisticRegression(random_state=42, max_iter = 1000))
])

# %%
lr.fit(X_train_transf, y_train)
# Out:
# Pipeline(steps=[('lr', LogisticRegression(max_iter=1000, random_state=42))])

# %% [markdown]
# ## Avaliação do modelo

# %% [markdown]
# ### Acurácia

# %%
y_pred_train = lr.predict(X_train_transf)
y_pred_test = lr.predict(X_test_transf)
from sklearn.metrics import accuracy_score

print('Acurácia Treino:', accuracy_score(y_train, y_pred_train))
print('Acurácia Teste:', accuracy_score(y_test, y_pred_test))
# Out:
# Acurácia Treino: 0.7949414823138367
# Acurácia Teste: 0.8035658943975681

# %% [markdown]
# ### AUROC

# %%
from sklearn.metrics import roc_auc_score

y_proba = lr.predict_proba(X_train_transf)[:, 1]

y_proba_test = lr.predict_proba(X_test_transf)[:, 1]


print('AUC Treino:', roc_auc_score(y_train, y_proba))
print('AUC Teste:', roc_auc_score(y_test, y_proba_test))
# Out:
# AUC Treino: 0.8418734651953353
# AUC Teste: 0.8474017064499967

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=['Alta', 'Obito']))
# Out:
#               precision    recall  f1-score   support
#
#         Alta       0.83      0.91      0.87    259618
#        Obito       0.72      0.56      0.63    111453
#
#     accuracy                           0.80    371071
#    macro avg       0.77      0.74      0.75    371071
# weighted avg       0.80      0.80      0.80    371071

# %% [markdown]
# ## Coeficientes

# %%
coefs = pd.DataFrame(data = {
    'Colunas': X_train_transf.columns,
    'Coeficientes': lr.steps[-1][1].coef_.ravel()
})

# %%
coefs_ordenado = coefs.reindex(coefs.Coeficientes.abs().sort_values(ascending = False).index).reset_index(drop=True)

# %%
coefs_ordenado.loc[0, :] = ['Intercepto', lr.steps[-1][1].intercept_]
# Out:
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
coefs_ordenado
# Out:
#                                     Colunas  Coeficientes
# 0                                Intercepto      1.074770
# 1                     suporte_vent_Invasivo      1.379579
# 2                       idade1_(63.0, 75.0]      1.097228
# 3                              positivo_vsr     -0.948461
# 4                          suporte_vent_Nao     -0.915758
# 5                     diagnostico_Influenza     -0.862830
# 6                        mae_vacinada_gripe     -0.732715
# 7                  diagnostico_Desconhecido     -0.721748
# 8                             positivo_rino     -0.714222
# 9                            imunodepre_Sim      0.701256
# 10                       diagnostico_Outros     -0.675809
# 11                            positivo_boca     -0.673068
# 12                                  uti_Nao     -0.619545
# 13                    idade1_(-0.001, 39.0]     -0.613364
# 14                suporte_vent_Nao-invasivo     -0.612414
# 15                             hepatica_Nao     -0.589007
# 16                            hepatica_Nulo     -0.585800
# 17                            sind_down_Sim      0.572694
# 18                           positivo_para3     -0.541892
# 19                        hepatica_Ignorado     -0.539756
# 20                      idade1_(53.0, 63.0]      0.517253
# 21                                renal_Sim      0.495314
# 22                             mae_amamenta     -0.493735
# 23                            saturacao_Nao     -0.473848
# 24                           positivo_metap     -0.453792
# 25     tempo_alta_obito_final1_(35.0, 84.0]     -0.424885
# 26                                 asma_Sim     -0.422067
# 27   tempo_alta_obito_final1_(161.0, 703.0]     -0.405461
# 28                                 gravidez     -0.394075
# 29                        puerpera_Ignorado     -0.391172
# 30                           positivo_para1     -0.385758
# 31    tempo_alta_obito_final1_(84.0, 161.0]     -0.384406
# 32                           neurologic_Sim      0.367692
# 33                                tosse_Sim     -0.367008
# 34                            desc_resp_Sim      0.331225
# 35                           saturacao_Nulo     -0.324651
# 36     tempo_alta_obito_final1_(14.0, 35.0]     -0.309362
# 37                            perd_pala_Sim     -0.278690
# 38                           sind_down_Nulo      0.278266
# 39                          cardiopati_Nulo     -0.276516
# 40                           cardiopati_Sim     -0.275361
# 41                        suporte_vent_Nulo     -0.269693
# 42                      hematologi_Ignorado     -0.261978
# 43                            saturacao_Sim     -0.259824
# 44                                  uti_Sim      0.253115
# 45                            antiviral_Sim     -0.249539
# 46                                 uti_Nulo      0.234921
# 47                           hematologi_Nao     -0.219429
# 48                           positivo_para2     -0.217770
# 49                          hematologi_Nulo     -0.210644
# 50                              fadiga_Nulo      0.210334
# 51                         vacina_gripe_Sim     -0.200920
# 52                             diarreia_Sim     -0.199916
# 53                           obesidade_Nulo     -0.196700
# 54                       vacina_covid19_Nao      0.192374
# 55                           cardiopati_Nao     -0.185916
# 56                                tosse_Nao     -0.184404
# 57                            diabetes_Nulo     -0.162461
# 58                                febre_Sim     -0.153812
# 59                            sind_down_Nao      0.151331
# 60                            perd_pala_Nao     -0.149677
# 61                             dispneia_Sim      0.148326
# 62                                CS_SEXO_M      0.146742
# 63            vacina_covid19_Nao-disponivel     -0.143014
# 64                              dor_abd_Sim      0.137237
# 65                            perd_olft_Sim     -0.133993
# 66                                febre_Nao     -0.123003
# 67                           perd_pala_Nulo     -0.118781
# 68                           positivo_adeno      0.116228
# 69                             diarreia_Nao     -0.110741
# 70                           pneumopati_Sim      0.103340
# 71                            diarreia_Nulo     -0.099619
# 72                             diabetes_Nao     -0.099601
# 73                               fadiga_Nao      0.090515
# 74                             puerpera_Nao     -0.086446
# 75                             dispneia_Nao     -0.085103
# 76                               tosse_Nulo     -0.084260
# 77                                 asma_Nao     -0.080511
# 78                            antiviral_Nao     -0.079171
# 79                            perd_olft_Nao     -0.076649
# 80                              vomito_Nulo     -0.075787
# 81                            obesidade_Sim      0.071141
# 82                              dor_abd_Nao      0.069152
# 83                           positivo_para4     -0.066688
# 84                            obesidade_Nao     -0.065407
# 85                          pneumopati_Nulo     -0.063084
# 86                       positivo_influenza     -0.061491
# 87                           desc_resp_Nulo      0.061246
# 88                            desc_resp_Nao      0.060976
# 89                             dor_abd_Nulo      0.060256
# 90                          neurologic_Nulo     -0.058683
# 91                                asma_Nulo     -0.058200
# 92                               vomito_Nao      0.057412
# 93                        dispneia_Ignorado      0.057082
# 94                               febre_Nulo     -0.056072
# 95                           positivo_sars2      0.050121
# 96                                renal_Nao      0.049903
# 97                           perd_olft_Nulo      0.044919
# 98                               vomito_Sim      0.044133
# 99                          imunodepre_Nulo      0.043371
# 100                           puerpera_Nulo     -0.034752
# 101                          pneumopati_Nao      0.029188
# 102                       vacina_gripe_Nulo     -0.026627
# 103                        vacina_gripe_Nao      0.020565
# 104                            garganta_Nao      0.016562
# 105                      vacina_covid19_Sim     -0.014238
# 106                          neurologic_Nao     -0.007989
# 107                              renal_Nulo      0.007965
# 108                            diabetes_Sim      0.007916
# 109                           garganta_Nulo     -0.007286
# 110                      antiviral_Ignorado      0.004064
# 111                          imunodepre_Nao      0.003414
# 112                              fadiga_Sim     -0.002199
# 113                            garganta_Sim      0.002132
# 114                     vacina_covid19_Nulo     -0.002105

# %% [markdown]
# Observa-se que a regressão logística considera que suporte ventilatório, idade, diagnósticos e algumas comorbidades como mais importantes para o óbito (coefs positivos), porém, trata-se de um banco com muitas colunas, assim a regressão logística não é muito indicada, melhor permanecer com a árvore.

# %% [markdown]
# ### Utilizando o class_weight = 'balanced'

# %%
lr = Pipeline(steps=[
    ('lr', LogisticRegression(random_state=42, max_iter = 1000, class_weight='balanced'))
])

# %%
lr.fit(X_train_transf, y_train)
# Out:
# Pipeline(steps=[('lr',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %% [markdown]
# ## Avaliação do modelo

# %% [markdown]
# ### Acurácia

# %%
y_pred_train = lr.predict(X_train_transf)
y_pred_test = lr.predict(X_test_transf)
from sklearn.metrics import accuracy_score

print('Acurácia Treino:', accuracy_score(y_train, y_pred_train))
print('Acurácia Teste:', accuracy_score(y_test, y_pred_test))
# Out:
# Acurácia Treino: 0.7664971876226789
# Acurácia Teste: 0.7685725912291718

# %% [markdown]
# ### AUROC

# %%
from sklearn.metrics import roc_auc_score

y_proba = lr.predict_proba(X_train_transf)[:, 1]

y_proba_test = lr.predict_proba(X_test_transf)[:, 1]


print('AUC Treino:', roc_auc_score(y_train, y_proba))
print('AUC Teste:', roc_auc_score(y_test, y_proba_test))
# Out:
# AUC Treino: 0.841993499727752
# AUC Teste: 0.8474905455649809

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=['Alta', 'Obito']))
# Out:
#               precision    recall  f1-score   support
#
#         Alta       0.88      0.77      0.82    259618
#        Obito       0.59      0.76      0.66    111453
#
#     accuracy                           0.77    371071
#    macro avg       0.74      0.77      0.74    371071
# weighted avg       0.79      0.77      0.78    371071

# %% [markdown]
# ## Coeficientes

# %%
coefs = pd.DataFrame(data = {
    'Colunas': X_train_transf.columns,
    'Coeficientes': lr.steps[-1][1].coef_.ravel()
})

# %%
coefs_ordenado = coefs.reindex(coefs.Coeficientes.abs().sort_values(ascending = False).index).reset_index(drop=True)

# %%
coefs_ordenado.loc[0, :] = ['Intercepto', lr.steps[-1][1].intercept_]
# Out:
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
coefs_ordenado
# Out:
#                                     Colunas  Coeficientes
# 0                                Intercepto      1.969050
# 1                     suporte_vent_Invasivo      1.396828
# 2                       idade1_(63.0, 75.0]      1.111321
# 3                              positivo_vsr     -0.982312
# 4                          suporte_vent_Nao     -0.915479
# 5                     diagnostico_Influenza     -0.857749
# 6                            imunodepre_Sim      0.737448
# 7                             positivo_rino     -0.704383
# 8                             sind_down_Sim      0.697561
# 9                  diagnostico_Desconhecido     -0.685238
# 10                                  uti_Nao     -0.640978
# 11                       diagnostico_Outros     -0.638460
# 12                       mae_vacinada_gripe     -0.635106
# 13                    idade1_(-0.001, 39.0]     -0.631669
# 14                             hepatica_Nao     -0.625229
# 15                            hepatica_Nulo     -0.601656
# 16                suporte_vent_Nao-invasivo     -0.600452
# 17                        hepatica_Ignorado     -0.570129
# 18                      idade1_(53.0, 63.0]      0.525950
# 19                                renal_Sim      0.482607
# 20                            saturacao_Nao     -0.480515
# 21                             mae_amamenta     -0.474318
# 22                                 asma_Sim     -0.444092
# 23                        puerpera_Ignorado     -0.404641
# 24                                 gravidez     -0.397971
# 25                                tosse_Sim     -0.393013
# 26     tempo_alta_obito_final1_(35.0, 84.0]     -0.384938
# 27                           neurologic_Sim      0.381897
# 28   tempo_alta_obito_final1_(161.0, 703.0]     -0.377285
# 29                           positivo_metap     -0.375235
# 30    tempo_alta_obito_final1_(84.0, 161.0]     -0.354400
# 31                            desc_resp_Sim      0.341542
# 32                           saturacao_Nulo     -0.332421
# 33                      hematologi_Ignorado     -0.326504
# 34                           sind_down_Nulo      0.308997
# 35                          cardiopati_Nulo     -0.307687
# 36                            positivo_boca     -0.300335
# 37                           cardiopati_Sim     -0.296007
# 38                            perd_pala_Sim     -0.273983
# 39                        suporte_vent_Nulo     -0.264886
# 40                           positivo_para3     -0.263523
# 41     tempo_alta_obito_final1_(14.0, 35.0]     -0.259658
# 42                            antiviral_Sim     -0.254979
# 43                           hematologi_Nao     -0.251224
# 44                            saturacao_Sim     -0.251175
# 45                                  uti_Sim      0.250498
# 46                          hematologi_Nulo     -0.228290
# 47                                 uti_Nulo      0.227382
# 48                             diarreia_Sim     -0.207876
# 49                           obesidade_Nulo     -0.204198
# 50                         vacina_gripe_Sim     -0.202930
# 51                       vacina_covid19_Nao      0.200906
# 52                                tosse_Nao     -0.199938
# 53                              fadiga_Nulo      0.197243
# 54                           cardiopati_Nao     -0.195289
# 55                           positivo_para1     -0.188012
# 56                            sind_down_Nao      0.172730
# 57                            diabetes_Nulo     -0.168933
# 58                                febre_Sim     -0.161014
# 59                             dispneia_Sim      0.159808
# 60                            perd_pala_Nao     -0.145917
# 61                                CS_SEXO_M      0.144990
# 62                            perd_olft_Sim     -0.144873
# 63                              dor_abd_Sim      0.142545
# 64            vacina_covid19_Nao-disponivel     -0.136205
# 65                                febre_Nao     -0.126452
# 66                             diarreia_Nao     -0.114967
# 67                           perd_pala_Nulo     -0.111187
# 68                            diarreia_Nulo     -0.107230
# 69                               tosse_Nulo     -0.102951
# 70                             puerpera_Nao     -0.102136
# 71                             diabetes_Nao     -0.099126
# 72                           positivo_para2     -0.098272
# 73                           pneumopati_Sim      0.089101
# 74                            obesidade_Sim      0.087172
# 75                          pneumopati_Nulo     -0.084061
# 76                            antiviral_Nao     -0.083980
# 77                               fadiga_Nao      0.080958
# 78                            perd_olft_Nao     -0.080851
# 79                           positivo_adeno      0.079581
# 80                                 asma_Nao     -0.077838
# 81                              vomito_Nulo     -0.077234
# 82                             dispneia_Nao     -0.075148
# 83                          neurologic_Nulo     -0.068668
# 84                             dor_abd_Nulo      0.067447
# 85                              dor_abd_Nao      0.065409
# 86                            desc_resp_Nao      0.064975
# 87                            obesidade_Nao     -0.064054
# 88                                asma_Nulo     -0.063752
# 89                           desc_resp_Nulo      0.060983
# 90                               vomito_Nao      0.060099
# 91                        dispneia_Ignorado      0.058236
# 92                       positivo_influenza     -0.052383
# 93                               vomito_Sim      0.052367
# 94                               febre_Nulo     -0.052139
# 95                            puerpera_Nulo     -0.046183
# 96                           positivo_sars2      0.045764
# 97                           perd_olft_Nulo      0.036756
# 98                         vacina_gripe_Nao      0.032745
# 99                           positivo_para4     -0.032576
# 100                         imunodepre_Nulo      0.030099
# 101                       vacina_gripe_Nulo     -0.029629
# 102                            garganta_Nao      0.027882
# 103                              renal_Nulo     -0.024640
# 104                               renal_Nao      0.023507
# 105                              fadiga_Sim     -0.018899
# 106                      vacina_covid19_Sim     -0.015623
# 107                          pneumopati_Nao      0.015417
# 108                          neurologic_Nao     -0.014910
# 109                            garganta_Sim      0.011415
# 110                            diabetes_Sim      0.010846
# 111                     vacina_covid19_Nulo      0.009837
# 112                          imunodepre_Nao     -0.008876
# 113                      antiviral_Ignorado      0.006074
# 114                           garganta_Nulo      0.004746

# %% [markdown]
# Aplicar o class_weight = 'balanced' melhora o recall porém diminui a precisão.
#
# O modelo de regressão logística não teve muita diferença nos resultados quanto a árvore de decisão, porém acredito que a árvore de decisão tem melhor interpretabilidade e é mais fácil de explicar.
