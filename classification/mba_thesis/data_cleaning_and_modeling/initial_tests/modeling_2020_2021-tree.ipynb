# %% [markdown]
# # Modelagem Estatística
#
# ### Banco de 2021
#
# Para a modelagem estatística, irei utilizar uma árvore de decisão pois acredito ser a melhor opção para visualizar quais variáveis são mais e menos importantes na hora de determinar o óbito.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 25, 10

# %%
df = pd.read_csv('SRAG_2020_2021.csv', parse_dates=['DT_NOTIFIC'])

# %%
df.shape
# Out:
# (2261067, 51)

# %%
df.columns
# Out:
# Index(['DT_NOTIFIC', 'tempo_alta_obito_final', 'febre', 'tosse', 'dispneia',
#        'diarreia', 'vomito', 'garganta', 'desc_resp', 'saturacao', 'dor_abd',
#        'fadiga', 'perd_olft', 'perd_pala', 'hematologi', 'cardiopati', 'asma',
#        'diabetes', 'pneumopati', 'renal', 'imunodepre', 'hepatica',
#        'neurologic', 'obesidade', 'puerpera', 'sind_down', 'SG_UF_NOT',
#        'idade', 'CS_SEXO', 'gravidez', 'raca', 'vacina_gripe', 'mae_amamenta',
#        'mae_vacinada_gripe', 'EVOLUCAO', 'diagnostico', 'antiviral',
#        'suporte_vent', 'uti', 'positivo_vsr', 'positivo_para1',
#        'positivo_para2', 'positivo_para3', 'positivo_para4', 'positivo_adeno',
#        'positivo_sars2', 'positivo_influenza', 'positivo_metap',
#        'positivo_boca', 'positivo_rino', 'vacina_covid19'],
#       dtype='object')

# %%
for i in df.columns:
    print('Coluna: ', i, '\nTipo: ', type(df[i][0]))
    print('')
# Out:
# Coluna:  DT_NOTIFIC
# Tipo:  <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#
# Coluna:  tempo_alta_obito_final
# Tipo:  <class 'numpy.float64'>
#
# Coluna:  febre
# Tipo:  <class 'str'>
#
# Coluna:  tosse
# Tipo:  <class 'str'>
#
# Coluna:  dispneia
# Tipo:  <class 'str'>
#
# Coluna:  diarreia
# Tipo:  <class 'str'>
#
# Coluna:  vomito
# Tipo:  <class 'str'>
#
# Coluna:  garganta
# Tipo:  <class 'str'>
#
# Coluna:  desc_resp
# Tipo:  <class 'str'>
#
# Coluna:  saturacao
# Tipo:  <class 'str'>
#
# Coluna:  dor_abd
# Tipo:  <class 'str'>
#
# Coluna:  fadiga
# Tipo:  <class 'str'>
#
# Coluna:  perd_olft
# Tipo:  <class 'str'>
#
# Coluna:  perd_pala
# Tipo:  <class 'str'>
#
# Coluna:  hematologi
# Tipo:  <class 'str'>
#
# Coluna:  cardiopati
# Tipo:  <class 'str'>
#
# Coluna:  asma
# Tipo:  <class 'str'>
#
# Coluna:  diabetes
# Tipo:  <class 'str'>
#
# Coluna:  pneumopati
# Tipo:  <class 'str'>
#
# Coluna:  renal
# Tipo:  <class 'str'>
#
# Coluna:  imunodepre
# Tipo:  <class 'str'>
#
# Coluna:  hepatica
# Tipo:  <class 'str'>
#
# Coluna:  neurologic
# Tipo:  <class 'str'>
#
# Coluna:  obesidade
# Tipo:  <class 'str'>
#
# Coluna:  puerpera
# Tipo:  <class 'str'>
#
# Coluna:  sind_down
# Tipo:  <class 'str'>
#
# Coluna:  SG_UF_NOT
# Tipo:  <class 'str'>
#
# Coluna:  idade
# Tipo:  <class 'numpy.float64'>
#
# Coluna:  CS_SEXO
# Tipo:  <class 'str'>
#
# Coluna:  gravidez
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  raca
# Tipo:  <class 'str'>
#
# Coluna:  vacina_gripe
# Tipo:  <class 'str'>
#
# Coluna:  mae_amamenta
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  mae_vacinada_gripe
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  EVOLUCAO
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  diagnostico
# Tipo:  <class 'str'>
#
# Coluna:  antiviral
# Tipo:  <class 'str'>
#
# Coluna:  suporte_vent
# Tipo:  <class 'str'>
#
# Coluna:  uti
# Tipo:  <class 'str'>
#
# Coluna:  positivo_vsr
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_para1
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_para2
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_para3
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_para4
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_adeno
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_sars2
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_influenza
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_metap
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_boca
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  positivo_rino
# Tipo:  <class 'numpy.int64'>
#
# Coluna:  vacina_covid19
# Tipo:  <class 'str'>

# %% [markdown]
# ## Seleção das variáveis numéricas e categóricas
#
# Também irei retirar algumas variáveis da análise, como Raça e Estado

# %%
delete_vars = ['raca', 'SG_UF_NOT', 'EVOLUCAO', 'DT_NOTIFIC']
num_vars = ['tempo_alta_obito_final', 'idade']
dummy_vars = ['gravidez', 'mae_amamenta', 'mae_vacinada_gripe', 'positivo_vsr', 'positivo_para1', 'positivo_para2', 
              'positivo_para3', 'positivo_para4', 'positivo_adeno', 'positivo_sars2', 'positivo_influenza', 'positivo_metap',
             'positivo_boca', 'positivo_rino']

cat_vars = [i for i in df.columns if (i not in delete_vars) and (i not in num_vars) and (i not in dummy_vars)]

model_vars = cat_vars + num_vars + dummy_vars

# %%
len(model_vars)
# Out:
# 47

# %% [markdown]
# ### Separando em treino e teste (OOT)
#
# O banco de teste será OOT (Out of time). Pode-se ver pela variável DT_NOTIFIC que o banco vai de 29/12/2019 até 09/12/2021 (provável erro). Vou utilizar como treino os casos do início até 31 de junho de 2021. A partir de 01 de julho de 2021 será utilizado como teste (OOT).
#
# Essa divisão traz uma proporção de, aproximadamente 19,7% para teste

# %%
df[['DT_NOTIFIC']].describe(datetime_is_numeric=True)
# Out:
#                           DT_NOTIFIC
# count                        2261067
# mean   2021-01-07 20:22:27.490544384
# min              2019-12-29 00:00:00
# 25%              2020-08-09 00:00:00
# 50%              2021-02-04 00:00:00
# 75%              2021-05-23 00:00:00
# max              2021-12-09 00:00:00

# %%
data_corte = pd.to_datetime('2021-07-01')

df_train = df[df['DT_NOTIFIC'] <= data_corte].reset_index().copy()
df_test = df[df['DT_NOTIFIC'] >= data_corte].reset_index().copy()

# %%
df_train.shape, df_test.shape
# Out:
# ((1893438, 52), (372403, 52))

# %%
X_train = df_train[model_vars].copy()
y_train = df_train['EVOLUCAO'].copy()

X_test = df_test[model_vars].copy()
y_test = df_test['EVOLUCAO'].copy()

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.689948
# 1    0.310052
# Name: EVOLUCAO, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.700271
# 1    0.299729
# Name: EVOLUCAO, dtype: float64

# %% [markdown]
# A proporção entre 0 e 1 de teste e treino é próxima.

# %% [markdown]
# ## Modelagem - Árvore de decisão

# %% [markdown]
# Inicialmente vou testar qual a max_depth que traz a maior acurácia para o modelo. Vou treinar vários modelos para plotar o gráfico de acurácia no teste

# %%
from sklearn.pipeline import Pipeline
from feature_engine.encoding import OneHotEncoder
from feature_engine.wrappers import SklearnTransformerWrapper

from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.metrics import accuracy_score

# %% [markdown]
# Para não ter que aplicar em cada loop a transformação das colunas categóricas em dummy, vou fazer o processo apenas 1 vez e aplicar no modelo

# %%
onehot = OneHotEncoder()

# %%
X_train_transf = onehot.fit_transform(X_train)

X_test_transf = onehot.transform(X_test)
# Out:
# C:\Users\guilh\anaconda3\envs\fia-tcc\lib\site-packages\feature_engine\encoding\one_hot.py:276: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[str(feature) + "_" + str(category)] = np.where(

# %% [markdown]
# ### Baseline - Modelo sem ajuste de hiperparâmetros

# %%
dt = Pipeline(steps=[
    # ('one_hot_encoder', OneHotEncoder(variables=cat_vars)),
    ('dt', DecisionTreeClassifier(random_state=42))
])

# %%
dt.fit(X_train_transf, y_train)
# Out:
# Pipeline(steps=[('dt', DecisionTreeClassifier(random_state=42))])

# %% [markdown]
# ## Avaliação do modelo

# %% [markdown]
# ### Acurácia

# %%
y_pred_train = dt.predict(X_train_transf)
y_pred_test = dt.predict(X_test_transf)
from sklearn.metrics import accuracy_score

print('Acurácia Treino:', accuracy_score(y_train, y_pred_train))
print('Acurácia Teste:', accuracy_score(y_test, y_pred_test))
# Out:
# Acurácia Treino: 0.9997089949604898
# Acurácia Teste: 0.7244195132692272

# %% [markdown]
# ### AUROC

# %%
from sklearn.metrics import roc_auc_score

y_proba = dt.predict_proba(X_train_transf)[:, 1]

y_proba_test = dt.predict_proba(X_test_transf)[:, 1]


print('AUC Treino:', roc_auc_score(y_train, y_proba))
print('AUC Teste:', roc_auc_score(y_test, y_proba_test))
# Out:
# AUC Treino: 0.9999997996162251
# AUC Teste: 0.6832462164858212

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=['Alta', 'Obito']))
# Out:
#               precision    recall  f1-score   support
#
#         Alta       0.81      0.79      0.80    260783
#        Obito       0.54      0.58      0.56    111620
#
#     accuracy                           0.72    372403
#    macro avg       0.68      0.68      0.68    372403
# weighted avg       0.73      0.72      0.73    372403

# %% [markdown]
# ## Feature Importances
#
# Entendendo quais são as características que não podem faltar na triagem de um paciente com suspeita de SRAG

# %%
pd.set_option('display.max_rows', 140)

feature_importances_df = pd.DataFrame({
    'features': X_train_transf.columns,
    'importances': dt.steps[-1][1].feature_importances_
}).sort_values(by='importances', ascending=False)

feature_importances_df
# Out:
#                           features  importances
# 127          suporte_vent_Invasivo     0.179608
# 0           tempo_alta_obito_final     0.166206
# 1                            idade     0.158644
# 131                        uti_Nao     0.029665
# 121              diagnostico_COVID     0.013354
# 11                  positivo_sars2     0.011738
# 117          vacina_gripe_Ignorado     0.011029
# 16                       febre_Sim     0.010833
# 114               vacina_gripe_Nao     0.010712
# 122                  antiviral_Nao     0.010587
# 69                  cardiopati_Sim     0.009293
# 20                       tosse_Sim     0.008782
# 116              vacina_gripe_Nulo     0.008751
# 124             antiviral_Ignorado     0.008735
# 113                      CS_SEXO_F     0.008554
# 112                      CS_SEXO_M     0.008456
# 136            vacina_covid19_Nulo     0.008403
# 37                    garganta_Sim     0.008397
# 135  vacina_covid19_Nao-disponivel     0.008321
# 44                   saturacao_Sim     0.008295
# 17                       febre_Nao     0.008053
# 77                    diabetes_Sim     0.007851
# 24                    dispneia_Sim     0.007829
# 54                      fadiga_Sim     0.007744
# 115               vacina_gripe_Sim     0.007480
# 29                    diarreia_Sim     0.007417
# 123                  antiviral_Sim     0.007248
# 125                 antiviral_Nulo     0.007127
# 40                   desc_resp_Sim     0.006600
# 137             vacina_covid19_Nao     0.006386
# 21                       tosse_Nao     0.006304
# 36                    garganta_Nao     0.006288
# 70                  cardiopati_Nao     0.006046
# 53                      fadiga_Nao     0.005984
# 139        vacina_covid19_Ignorado     0.005876
# 33                      vomito_Sim     0.005814
# 45                   saturacao_Nao     0.005614
# 26                    dispneia_Nao     0.005427
# 138             vacina_covid19_Sim     0.005425
# 28                    diarreia_Nao     0.005412
# 68                 cardiopati_Nulo     0.005276
# 102                  obesidade_Sim     0.004983
# 78                    diabetes_Nao     0.004814
# 128               suporte_vent_Nao     0.004686
# 18                      febre_Nulo     0.004676
# 80                  pneumopati_Sim     0.004488
# 32                      vomito_Nao     0.004273
# 46                  saturacao_Nulo     0.004114
# 98                  neurologic_Sim     0.004104
# 76                   diabetes_Nulo     0.003966
# 86                       renal_Sim     0.003939
# 126      suporte_vent_Nao-invasivo     0.003926
# 50                     dor_abd_Sim     0.003746
# 38                   garganta_Nulo     0.003741
# 62                   perd_pala_Sim     0.003680
# 129              suporte_vent_Nulo     0.003664
# 58                   perd_olft_Sim     0.003616
# 27                   dispneia_Nulo     0.003598
# 52                     fadiga_Nulo     0.003594
# 41                   desc_resp_Nao     0.003566
# 49                     dor_abd_Nao     0.003534
# 22                      tosse_Nulo     0.003450
# 61                   perd_pala_Nao     0.003444
# 88                  imunodepre_Sim     0.003346
# 101                  obesidade_Nao     0.003297
# 57                   perd_olft_Nao     0.003277
# 74                        asma_Sim     0.003056
# 30                   diarreia_Nulo     0.002945
# 100                 obesidade_Nulo     0.002915
# 132                        uti_Sim     0.002860
# 82                  pneumopati_Nao     0.002630
# 130          suporte_vent_Ignorado     0.002589
# 42                  desc_resp_Nulo     0.002584
# 34                     vomito_Nulo     0.002456
# 133                       uti_Nulo     0.002407
# 56                  perd_olft_Nulo     0.002286
# 60                  perd_pala_Nulo     0.002243
# 48                    dor_abd_Nulo     0.002097
# 95                    hepatica_Sim     0.001897
# 73                        asma_Nao     0.001893
# 81                 pneumopati_Nulo     0.001855
# 85                       renal_Nao     0.001842
# 119       diagnostico_Desconhecido     0.001755
# 97                  neurologic_Nao     0.001739
# 84                      renal_Nulo     0.001692
# 134                   uti_Ignorado     0.001575
# 72                       asma_Nulo     0.001467
# 67                  hematologi_Sim     0.001450
# 90                  imunodepre_Nao     0.001446
# 105                   puerpera_Nao     0.001413
# 96                 neurologic_Nulo     0.001399
# 89                 imunodepre_Nulo     0.001316
# 104                  puerpera_Nulo     0.001222
# 47              saturacao_Ignorado     0.001201
# 65                  hematologi_Nao     0.001071
# 93                    hepatica_Nao     0.001068
# 39               garganta_Ignorado     0.001056
# 92                   hepatica_Nulo     0.001013
# 103             obesidade_Ignorado     0.000977
# 19                  febre_Ignorado     0.000885
# 64                 hematologi_Nulo     0.000858
# 55                 fadiga_Ignorado     0.000843
# 63              perd_pala_Ignorado     0.000841
# 59              perd_olft_Ignorado     0.000826
# 106              puerpera_Ignorado     0.000823
# 109                  sind_down_Nao     0.000776
# 31               diarreia_Ignorado     0.000763
# 35                 vomito_Ignorado     0.000759
# 51                dor_abd_Ignorado     0.000728
# 110                  sind_down_Sim     0.000674
# 23                  tosse_Ignorado     0.000667
# 108                 sind_down_Nulo     0.000648
# 43              desc_resp_Ignorado     0.000557
# 25               dispneia_Ignorado     0.000502
# 2                         gravidez     0.000497
# 118             diagnostico_Outros     0.000432
# 71             cardiopati_Ignorado     0.000377
# 79               diabetes_Ignorado     0.000300
# 83             pneumopati_Ignorado     0.000269
# 107                   puerpera_Sim     0.000246
# 99             neurologic_Ignorado     0.000241
# 87                  renal_Ignorado     0.000239
# 91             imunodepre_Ignorado     0.000238
# 66             hematologi_Ignorado     0.000231
# 111             sind_down_Ignorado     0.000229
# 75                   asma_Ignorado     0.000225
# 94               hepatica_Ignorado     0.000213
# 120          diagnostico_Influenza     0.000126
# 12              positivo_influenza     0.000112
# 3                     mae_amamenta     0.000095
# 15                   positivo_rino     0.000093
# 5                     positivo_vsr     0.000090
# 10                  positivo_adeno     0.000037
# 4               mae_vacinada_gripe     0.000028
# 13                  positivo_metap     0.000015
# 6                   positivo_para1     0.000009
# 14                   positivo_boca     0.000005
# 8                   positivo_para3     0.000003
# 9                   positivo_para4     0.000002
# 7                   positivo_para2     0.000000

# %%
pd.reset_option('display.max_rows')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (10,7))
plt.title("Feature importances")
sns.barplot(data = feature_importances_df[:15], x = 'importances', y = 'features')
plt.show()

# %%
import shap

explainer = shap.Explainer(dt.steps[-1][1])
shap_values = explainer(X_test_transf)

shap.plots.beeswarm(shap_values[:, :, 1], max_display = 20)

# %% [markdown]
# ### Modelo com ajuste de hiperparâmetros

# %% [markdown]
# Avaliação da profundidade da árvore e a acurácia do modelo

# %%
# %%time

profundidade = []
acuracia = []

for depth in range(1, 31):
    dt = Pipeline(steps=[
        # ('one_hot_encoder', OneHotEncoder(variables=cat_vars)),
        ('dt', DecisionTreeClassifier(random_state=42, max_depth=depth))
    ])
    
    dt.fit(X_train_transf, y_train)
    
    y_pred_test = dt.predict(X_test_transf)
    accuracy = accuracy_score(y_test, y_pred_test)
    
    profundidade.append(depth)
    acuracia.append(accuracy)
    
    print('Profundidade:', depth, '\nAcurácia:', accuracy)
    print('')
# Out:
# Profundidade: 1
# Acurácia: 0.7858771277352761
#
# Profundidade: 2
# Acurácia: 0.7858771277352761
#
# Profundidade: 3
# Acurácia: 0.7894163043799325
#
# Profundidade: 4
# Acurácia: 0.7986750912318107
#
# Profundidade: 5
# Acurácia: 0.8017443468500522
#
# Profundidade: 6
# Acurácia: 0.8041181193491996
#
# Profundidade: 7
# Acurácia: 0.8060944729231505
#
# Profundidade: 8
# Acurácia: 0.8072733033837
#
# Profundidade: 9
# Acurácia: 0.8079553601877536
#
# Profundidade: 10
# Acurácia: 0.8087716801422116
#
# Profundidade: 11
# Acurácia: 0.8090402064430201
#
# Profundidade: 12
# Acurácia: 0.8092684537987073
#
# Profundidade: 13
# Acurácia: 0.8090375211800119
#
# Profundidade: 14
# Acurácia: 0.8077969296702766
#
# Profundidade: 15
# Acurácia: 0.8065294855304603
#
# Profundidade: 16
# Acurácia: 0.8043356256528545
#
# Profundidade: 17
# Acurácia: 0.8020262994659012
#
# Profundidade: 18
# Acurácia: 0.7981111860001128
#
# Profundidade: 19
# Acurácia: 0.794375985155866
#
# Profundidade: 20
# Acurácia: 0.7904581864270696
#
# Profundidade: 21
# Acurácia: 0.7869431771494859
#
# Profundidade: 22
# Acurácia: 0.7813712564077089
#
# Profundidade: 23
# Acurácia: 0.7772359513752575
#
# Profundidade: 24
# Acurácia: 0.7724749800619222
#
# Profundidade: 25
# Acurácia: 0.7674320561327379
#
# Profundidade: 26
# Acurácia: 0.7626952521864754
#
# Profundidade: 27
# Acurácia: 0.7572441682800621
#
# Profundidade: 28
# Acurácia: 0.7527436674785112
#
# Profundidade: 29
# Acurácia: 0.7495482044988896
#
# Profundidade: 30
# Acurácia: 0.74559281208798
#
# Wall time: 29min 12s

# %%
result_profundidade = pd.DataFrame(profundidade, columns=['Profundidade'])
result_profundidade['Acuracia'] = acuracia
result_profundidade
# Out:
#     Profundidade  Acuracia
# 0              1  0.785877
# 1              2  0.785877
# 2              3  0.789416
# 3              4  0.798675
# 4              5  0.801744
# 5              6  0.804118
# 6              7  0.806094
# 7              8  0.807273
# 8              9  0.807955
# 9             10  0.808772
# 10            11  0.809040
# 11            12  0.809268
# 12            13  0.809038
# 13            14  0.807797
# 14            15  0.806529
# 15            16  0.804336
# 16            17  0.802026
# 17            18  0.798111
# 18            19  0.794376
# 19            20  0.790458
# 20            21  0.786943
# 21            22  0.781371
# 22            23  0.777236
# 23            24  0.772475
# 24            25  0.767432
# 25            26  0.762695
# 26            27  0.757244
# 27            28  0.752744
# 28            29  0.749548
# 29            30  0.745593

# %% [markdown]
# Salvando para não precisar rodar novamente

# %%
result_profundidade.to_csv('resultados_loop_profundidade.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (12,8))
sns.lineplot(x = profundidade, y = acuracia)
plt.show()

# %% [markdown]
# Descobrindo o valor de profundidade que traz a maior acurácia

# %%
print('Maior acurácia:', max(acuracia), '\nProfundidade:', acuracia.index(max(acuracia))+1)
# Out:
# Maior acurácia: 0.8092684537987073
# Profundidade: 12

# %% [markdown]
# Apesar da profundidade 12 ser a árvore com melhor acurácia, o banco é muito grande e esta profundidade dificulta a plotagem da árvore e sua interpretação. Com isso em mente, vou montar o modelo com 7 de profundidade. Além disso, como o banco de dados tem muitas linhas, testarei 10 possibilidades de min_samples_leaf, de 2 a 1000 de 100 em 100 para ver se há alteração na acurácia. O aumento do min_samples_leaf faz com que a árvore diminua suas quebras, já que precisa que mais amostras para realizar uma quebra.

# %%
# %%time

samp_leaf = [2, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

acuracia = []

for samples_leaf in samp_leaf:
    dt = Pipeline(steps=[
        # ('one_hot_encoder', OneHotEncoder(variables=cat_vars)),
        ('dt', DecisionTreeClassifier(random_state=42, max_depth=7, min_samples_leaf=samples_leaf))
    ])
    
    dt.fit(X_train_transf, y_train)
    
    y_pred_test = dt.predict(X_test_transf)
    accuracy = accuracy_score(y_test, y_pred_test)
    
    acuracia.append(accuracy)
    
    print('min_samples_leaf:', samples_leaf, '\nAcurácia:', accuracy)
    print('')
# Out:
# min_samples_leaf: 2
# Acurácia: 0.8060971581861586
#
# min_samples_leaf: 100
# Acurácia: 0.8060756760820939
#
# min_samples_leaf: 200
# Acurácia: 0.8060595645040454
#
# min_samples_leaf: 300
# Acurácia: 0.8059736360877866
#
# min_samples_leaf: 400
# Acurácia: 0.805799093992261
#
# min_samples_leaf: 500
# Acurácia: 0.8058071497812853
#
# min_samples_leaf: 600
# Acurácia: 0.8057776118881964
#
# min_samples_leaf: 700
# Acurácia: 0.8056514045268164
#
# min_samples_leaf: 800
# Acurácia: 0.8056191813707193
#
# min_samples_leaf: 900
# Acurácia: 0.8056889982089296
#
# min_samples_leaf: 1000
# Acurácia: 0.805578902425598
#
# Wall time: 5min 47s

# %%
plt.figure(figsize = (12,8))
sns.lineplot(x = samp_leaf, y = acuracia)
plt.show()

# %% [markdown]
# Como a acurácia vai descendo com o aumento do min_samples_leaf, vou utilizar 100 para diminuir o tamanho da árvore que será plotada.

# %%
dt = Pipeline(steps=[
    # ('one_hot_encoder', OneHotEncoder(variables=cat_vars)),
    ('dt', DecisionTreeClassifier(random_state=42, max_depth=7, min_samples_leaf=1000))
])

# %%
dt.fit(X_train_transf, y_train)
# Out:
# Pipeline(steps=[('dt',
#                  DecisionTreeClassifier(max_depth=7, min_samples_leaf=1000,
#                                         random_state=42))])

# %% [markdown]
# ## Avaliação do modelo

# %% [markdown]
# ### Acurácia

# %%
y_pred_train = dt.predict(X_train_transf)
y_pred_test = dt.predict(X_test_transf)
from sklearn.metrics import accuracy_score

print('Acurácia Treino:', accuracy_score(y_train, y_pred_train))
print('Acurácia Teste:', accuracy_score(y_test, y_pred_test))
# Out:
# Acurácia Treino: 0.7956326005921504
# Acurácia Teste: 0.805578902425598

# %% [markdown]
# ### AUROC

# %%
from sklearn.metrics import roc_auc_score

y_proba = dt.predict_proba(X_train_transf)[:, 1]

y_proba_test = dt.predict_proba(X_test_transf)[:, 1]


print('AUC Treino:', roc_auc_score(y_train, y_proba))
print('AUC Teste:', roc_auc_score(y_test, y_proba_test))
# Out:
# AUC Treino: 0.836730302625145
# AUC Teste: 0.8442652829805808

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test, target_names=['Alta', 'Obito']))
# Out:
#               precision    recall  f1-score   support
#
#         Alta       0.82      0.92      0.87    260783
#        Obito       0.74      0.54      0.63    111620
#
#     accuracy                           0.81    372403
#    macro avg       0.78      0.73      0.75    372403
# weighted avg       0.80      0.81      0.80    372403

# %% [markdown]
# ## Feature Importances
#
# Entendendo quais são as características que não podem faltar na triagem de um paciente com suspeita de SRAG

# %%
pd.set_option('display.max_rows', 140)

feature_importances_df = pd.DataFrame({
    'features': X_train_transf.columns,
    'importances': dt.steps[-1][1].feature_importances_
}).sort_values(by='importances', ascending=False)

feature_importances_df
# Out:
#                           features  importances
# 127          suporte_vent_Invasivo     0.550400
# 1                            idade     0.271910
# 131                        uti_Nao     0.088796
# 121              diagnostico_COVID     0.036164
# 0           tempo_alta_obito_final     0.034204
# 128               suporte_vent_Nao     0.006456
# 132                        uti_Sim     0.001757
# 100                 obesidade_Nulo     0.001596
# 40                   desc_resp_Sim     0.001413
# 20                       tosse_Sim     0.001308
# 135  vacina_covid19_Nao-disponivel     0.001201
# 44                   saturacao_Sim     0.000964
# 130          suporte_vent_Ignorado     0.000933
# 41                   desc_resp_Nao     0.000743
# 88                  imunodepre_Sim     0.000420
# 133                       uti_Nulo     0.000384
# 117          vacina_gripe_Ignorado     0.000354
# 26                    dispneia_Nao     0.000278
# 49                     dor_abd_Nao     0.000227
# 76                   diabetes_Nulo     0.000143
# 24                    dispneia_Sim     0.000116
# 101                  obesidade_Nao     0.000082
# 28                    diarreia_Nao     0.000071
# 56                  perd_olft_Nulo     0.000029
# 68                 cardiopati_Nulo     0.000028
# 73                        asma_Nao     0.000013
# 57                   perd_olft_Nao     0.000010
# 90                  imunodepre_Nao     0.000000
# 91             imunodepre_Ignorado     0.000000
# 92                   hepatica_Nulo     0.000000
# 122                  antiviral_Nao     0.000000
# 93                    hepatica_Nao     0.000000
# 137             vacina_covid19_Nao     0.000000
# 94               hepatica_Ignorado     0.000000
# 95                    hepatica_Sim     0.000000
# 96                 neurologic_Nulo     0.000000
# 89                 imunodepre_Nulo     0.000000
# 86                       renal_Sim     0.000000
# 87                  renal_Ignorado     0.000000
# 98                  neurologic_Sim     0.000000
# 85                       renal_Nao     0.000000
# 84                      renal_Nulo     0.000000
# 83             pneumopati_Ignorado     0.000000
# 82                  pneumopati_Nao     0.000000
# 138             vacina_covid19_Sim     0.000000
# 81                 pneumopati_Nulo     0.000000
# 80                  pneumopati_Sim     0.000000
# 79               diabetes_Ignorado     0.000000
# 78                    diabetes_Nao     0.000000
# 97                  neurologic_Nao     0.000000
# 99             neurologic_Ignorado     0.000000
# 136            vacina_covid19_Nulo     0.000000
# 120          diagnostico_Influenza     0.000000
# 119       diagnostico_Desconhecido     0.000000
# 118             diagnostico_Outros     0.000000
# 123                  antiviral_Sim     0.000000
# 124             antiviral_Ignorado     0.000000
# 116              vacina_gripe_Nulo     0.000000
# 115               vacina_gripe_Sim     0.000000
# 114               vacina_gripe_Nao     0.000000
# 113                      CS_SEXO_F     0.000000
# 112                      CS_SEXO_M     0.000000
# 111             sind_down_Ignorado     0.000000
# 110                  sind_down_Sim     0.000000
# 109                  sind_down_Nao     0.000000
# 108                 sind_down_Nulo     0.000000
# 107                   puerpera_Sim     0.000000
# 77                    diabetes_Sim     0.000000
# 105                   puerpera_Nao     0.000000
# 125                 antiviral_Nulo     0.000000
# 126      suporte_vent_Nao-invasivo     0.000000
# 104                  puerpera_Nulo     0.000000
# 103             obesidade_Ignorado     0.000000
# 129              suporte_vent_Nulo     0.000000
# 102                  obesidade_Sim     0.000000
# 134                   uti_Ignorado     0.000000
# 106              puerpera_Ignorado     0.000000
# 70                  cardiopati_Nao     0.000000
# 75                   asma_Ignorado     0.000000
# 16                       febre_Sim     0.000000
# 33                      vomito_Sim     0.000000
# 32                      vomito_Nao     0.000000
# 31               diarreia_Ignorado     0.000000
# 30                   diarreia_Nulo     0.000000
# 29                    diarreia_Sim     0.000000
# 27                   dispneia_Nulo     0.000000
# 25               dispneia_Ignorado     0.000000
# 23                  tosse_Ignorado     0.000000
# 22                      tosse_Nulo     0.000000
# 21                       tosse_Nao     0.000000
# 19                  febre_Ignorado     0.000000
# 18                      febre_Nulo     0.000000
# 17                       febre_Nao     0.000000
# 15                   positivo_rino     0.000000
# 74                        asma_Sim     0.000000
# 14                   positivo_boca     0.000000
# 13                  positivo_metap     0.000000
# 12              positivo_influenza     0.000000
# 11                  positivo_sars2     0.000000
# 10                  positivo_adeno     0.000000
# 9                   positivo_para4     0.000000
# 8                   positivo_para3     0.000000
# 7                   positivo_para2     0.000000
# 6                   positivo_para1     0.000000
# 5                     positivo_vsr     0.000000
# 4               mae_vacinada_gripe     0.000000
# 3                     mae_amamenta     0.000000
# 2                         gravidez     0.000000
# 34                     vomito_Nulo     0.000000
# 35                 vomito_Ignorado     0.000000
# 36                    garganta_Nao     0.000000
# 37                    garganta_Sim     0.000000
# 72                       asma_Nulo     0.000000
# 71             cardiopati_Ignorado     0.000000
# 69                  cardiopati_Sim     0.000000
# 67                  hematologi_Sim     0.000000
# 66             hematologi_Ignorado     0.000000
# 65                  hematologi_Nao     0.000000
# 64                 hematologi_Nulo     0.000000
# 63              perd_pala_Ignorado     0.000000
# 62                   perd_pala_Sim     0.000000
# 61                   perd_pala_Nao     0.000000
# 60                  perd_pala_Nulo     0.000000
# 59              perd_olft_Ignorado     0.000000
# 58                   perd_olft_Sim     0.000000
# 55                 fadiga_Ignorado     0.000000
# 54                      fadiga_Sim     0.000000
# 53                      fadiga_Nao     0.000000
# 52                     fadiga_Nulo     0.000000
# 51                dor_abd_Ignorado     0.000000
# 50                     dor_abd_Sim     0.000000
# 48                    dor_abd_Nulo     0.000000
# 47              saturacao_Ignorado     0.000000
# 46                  saturacao_Nulo     0.000000
# 45                   saturacao_Nao     0.000000
# 43              desc_resp_Ignorado     0.000000
# 42                  desc_resp_Nulo     0.000000
# 39               garganta_Ignorado     0.000000
# 38                   garganta_Nulo     0.000000
# 139        vacina_covid19_Ignorado     0.000000

# %%
pd.reset_option('display.max_rows')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (10,7))
plt.title("Feature importances")
sns.barplot(data = feature_importances_df[:15], x = 'importances', y = 'features')
plt.show()

# %%
plot_tree(
    dt.steps[-1][1],
    feature_names=X_train_transf.columns,
    class_names=['Alta', 'Obito'],
    rounded=True,
    filled=True,
    proportion=True
);

plt.savefig('tree_7_1000.pdf',format='pdf')

# %%
df.shape
# Out:
# (2261067, 51)

# %%
import shap

explainer = shap.Explainer(dt.steps[-1][1])
shap_values = explainer(X_test_transf)

shap.plots.beeswarm(shap_values[:, :, 1], max_display = 20) # 1 é o óbito e 0 a alta

# %% [markdown]
# ## Alterando o ponto de corte do modelo
#
# Para isso, vou utilizar o ROC através de uma função que irá retornar o ponto de corte ótimo que tem alta taxa de verdadeiros positivos e baixa taxa de falsos positivos

# %%
from sklearn.metrics import roc_curve, auc

def Find_Optimal_Cutoff(target, predicted):
    """ Find the optimal probability cutoff point for a classification model related to event rate
    Parameters
    ----------
    target : Matrix with dependent or target data, where rows are observations

    predicted : Matrix with predicted data, where rows are observations

    Returns
    -------     
    list type, with optimal cutoff value
        
    """
    fpr, tpr, threshold = roc_curve(target, predicted)
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'threshold' : pd.Series(threshold, index=i)})
    roc_t = roc.iloc[(roc.tf-0).abs().argsort()[:1]]

    return list(roc_t['threshold'])

# %%
threshold = Find_Optimal_Cutoff(y_train, y_proba)[0]
threshold
# Out:
# 0.2798892733564014

# %% [markdown]
# ### Treino

# %%
train_cuttoff_pred = []
for i in y_proba:
    if i > threshold:
        i = 1
        train_cuttoff_pred.append(i)
    else:
        i = 0
        train_cuttoff_pred.append(i)

# %%
cm = confusion_matrix(y_train, train_cuttoff_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
print(classification_report(y_train, train_cuttoff_pred, target_names=['Alta', 'Obito']))
# Out:
#               precision    recall  f1-score   support
#
#         Alta       0.87      0.78      0.82   1306373
#        Obito       0.60      0.73      0.66    587065
#
#     accuracy                           0.76   1893438
#    macro avg       0.73      0.76      0.74   1893438
# weighted avg       0.78      0.76      0.77   1893438

# %% [markdown]
# ### Teste

# %%
# Add prediction probability to dataframe
test_cuttoff_pred = []

for i in y_proba_test:
    if i > threshold:
        i = 1
        test_cuttoff_pred.append(i)
    else:
        i = 0
        test_cuttoff_pred.append(i)

# %%
cm = confusion_matrix(y_test, test_cuttoff_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
print(classification_report(y_test, test_cuttoff_pred, target_names=['Alta', 'Obito']))
# Out:
#               precision    recall  f1-score   support
#
#         Alta       0.88      0.79      0.83    260783
#        Obito       0.60      0.74      0.66    111620
#
#     accuracy                           0.77    372403
#    macro avg       0.74      0.76      0.75    372403
# weighted avg       0.79      0.77      0.78    372403
